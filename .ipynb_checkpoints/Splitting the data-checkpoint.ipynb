# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Transformed_Housing_Data_2 = pd.read_csv('Transformed_Housing_Data2.csv')

# %%
Transformed_Housing_Data_2.head(5)
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
Y = Transformed_Housing_Data_2.iloc[:,0]
X = Transformed_Housing_Data_2.iloc[:,1:31]
Y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: Sale_Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y , test_size=0.3)

# %%
X_train.shape
# Out:
# (15126, 30)

# %%
X_test.shape
# Out:
# (6483, 30)

# %%
Y_train.shape
# Out:
# (15126,)

# %%
Y_test.shape
# Out:
# (6483,)

# %%
train_test_split??

# %%
X.describe
# Out:
# <bound method NDFrame.describe of        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0                   3             1.00               1180.0
# 1                   3             2.25               2570.0
# 2                   2             1.00                770.0
# 3                   4             3.00               1960.0
# 4                   3             2.00               1680.0
# ...               ...              ...                  ...
# 21604               3             2.50               1530.0
# 21605               4             2.50               2310.0
# 21606               2             0.75               1020.0
# 21607               3             2.50               1600.0
# 21608               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0                  5650.0           1.0                    0              7
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_train
# Out:
# array([[-0.39185011, -1.44403302, -1.02189857, ..., -0.11157867,
#         -0.1698223 , -0.04228709],
#        [-0.39185011, -0.14350051, -0.2010576 , ..., -0.11157867,
#         -0.1698223 , -0.04228709],
#        [ 0.66713234,  1.48216513,  1.91123984, ..., -0.11157867,
#         -0.1698223 , -0.04228709],
#        ...,
#        [ 0.66713234,  0.50676574,  1.15606614, ..., -0.11157867,
#         -0.1698223 , -0.04228709],
#        [-0.39185011, -1.44403302, -0.86867492, ..., -0.11157867,
#         -0.1698223 , -0.04228709],
#        [-0.39185011, -0.79376677, -0.57317217, ..., -0.11157867,
#         -0.1698223 , -0.04228709]])

# %%
X_test =  scale.fit_transform(X_test)
X_test
# Out:
# array([[-0.41604165, -0.16164779, -0.7366522 , ..., -0.11388042,
#         -0.16656095, -0.05966885],
#        [-1.53289385, -0.80873802, -1.16727875, ..., -0.11388042,
#         -0.16656095, -0.05966885],
#        [ 0.70081054,  0.16189732,  0.28608585, ..., -0.11388042,
#         -0.16656095, -0.05966885],
#        ...,
#        [-0.41604165,  2.42671311,  0.49063346, ..., -0.11388042,
#         -0.16656095, -0.05966885],
#        [-0.41604165, -0.4851929 ,  0.10306956, ..., -0.11388042,
#         -0.16656095, -0.05966885],
#        [ 0.70081054,  0.48544244,  1.21193292, ..., -0.11388042,
#         -0.16656095, -0.05966885]])

# %%
Transformed_Housing_Data_2.describe()
# Out:
#          Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# count  2.160900e+04    21609.000000     21609.000000         21609.000000
# mean   5.116186e+05        3.370771         2.114709          2079.872553
# std    2.500620e+05        0.929916         0.770097           918.347816
# min    7.500000e+04        0.000000         0.000000           290.000000
# 25%    3.219500e+05        3.000000         1.750000          1430.000000
# 50%    4.500000e+05        3.000000         2.250000          1910.000000
# 75%    6.450000e+05        4.000000         2.500000          2550.000000
# max    1.129575e+06       33.000000         8.000000         13540.000000
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# count        2.160900e+04  21609.000000         21609.000000   21609.000000
# mean         1.510641e+04      1.494215             0.234347       7.623490
# ...

# %%
print("Before deleting outliers length = " , data['Sale Price'].count())                
target = data['Sale_Price']
target_mean = data['Sale Price'].mean()
target_sd = data['Sale Price'].std()
data = data['Sale Price'].drop()
print("After deleting outliers length = " , data['Sal'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9596/2156031593.py in <module>
# ----> 1 print("Before deleting outliers length = " , data['Sale Price'].count())
#       2 target = data['Sale_Price']
#       3 target_mean = data['Sale Price'].mean()
#       4 target_sd = data['Sale Price'].std()
#       5 data = data['Sale Price'].drop()
#
# NameError: name 'data' is not defined
